# %%
help(plt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf0176c47c2d> in <module>
# ----> 1 help(plt)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
plt.subplots(2,2)

# %%
import numpy as np
x=np.array([20,40,60,50,70])
y=np.array([30,35,55,80,50])
plt.subplot(2,2,1)
plt.plot(x,y,'r*',label='first row first column')
plt.legend()
plt.subplot(2,2,2)
plt.plot(x,y,'g^',label='first row and second column')
plt.legend()
plt.subplot(2,2,3)
plt.plot(x,y,'c+')
plt.subplot(2,2,4)
plt.plot(x,y,'k--')
plt.show()

# %%
pip install pandas

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/titanic.csv')

# %%
df

# %%
df.embarked.value_counts().plot(kind='bar',alpha=0.5)

# %%
x=np.array([20,40,60,50,70])
y=np.array([30,35,55,80,50])
plt.subplot(2,2,1)
plt.plot(x,y,'r*',label='first row first column')
df.embarked.value_counts().plot(kind='bar',alpha=0.5)
plt.legend()
plt.subplot(2,2,2)
plt.plot(x,y,'g^',label='first row and second column')
df.age.value_counts().plot(kind='bar',alpha=0.5)
plt.legend()
plt.subplot(2,2,3)
df.cabin.value_counts().plot(kind='bar',alpha=0.5)
plt.plot(x,y,'c+')
plt.subplot(2,2,4)
df.embarked.value_counts().plot(kind='bar',alpha=0.5)
plt.plot(x,y,'k--')
plt.show()

# %% [markdown]
# ## preproceesing

# %%
df.isnull().sum()

# %%
df.drop('cabin',axis=1,inplace=True)

# %%
df['age'].fillna(df['age'].mean(),inplace=True)

# %%
df.embarked.unique() ## unique elements

# %%
df['embarked'].fillna('S',inplace=True)
df

# %%
df.info()

# %%
df['embarked'].unique()

# %%
pd.get_dummies(df['embarked'])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Ie=LabelEncoder()

# %%
df['embarked']=Ie.fit_transform(df['embarked'])

# %%
df['embarked']

# %%
df['embarked'].unique()

# %% [markdown]
# ## scaling techniques
# - MinMax scalar
# - Robust scalar
# - standardization
# - Normalization

# %%
## MinMax Scalar
df['sex']=le.

# %%
pip sklearn.preprocessing pip

# %%
minmax=MinMaxScalar()

# %%
pip install sklearn.MinMaxScalar

# %%
from sklearn.preprocessing import minmax_scale

# %%
  from sklearn.preprocessing import normalize

# %% [markdown]
# ## seaborn
# - matplotlib
# - bokeh
# ## visualization tools
# - tableu
# - SAS
# - power Blue

# %%
import seaborn as sns

# %% [markdown]
# ## seaborn style plots
# - categorial scatter plots
# - strip plot
# - swarm plot
# - categorical distribution plots
# - box plot
# - voilin plot
# - catrgorical estimate plots
# - count plot
# - point plot
# - etc....

# %%
dir(sns) ## to find all the methos in the library

# %%
sns.set_style("ticks")
## white,whitegrid,ticks,dark,darkgrid

# %%
## inbiult datasets
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-62054a0a16b7> in <module>
#       1 ## inbiult datasets
# ----> 2 sns.get_dataset_names()
#
# NameError: name 'sns' is not defined

# %%
df=sns.load_dataset('mpg')
df

# %%
df.shape

# %%
df.columns

# %%
df['mpg'].count()

# %%
df['name'].value_counts()
## to get total noof values in the column

# %%
df.groupby('weight').count()

# %% [markdown]
# ## descriptive analysis or statistical analysis

# %%
df.info()

# %%
df.describe()

# %%
df.plot()

# %%
df.plot(kind='box')

# %%
df.plot(kind='hist' ,bins=2)
## histrogram plot uses bin to split graph into parts

# %%
sns.color_palette('dark')

# %%
import numpy as np
sns.color_palette(n_colors=5)

# %%
sns.color_palette(as_cmap=True)

# %%
sns.color_palette('PuBu')

# %%
sns.color_palette('BuGn')

# %%
sns.palplot('c',size=1)

# %%
sns.cubehelix_palette()
## n_colors to get no of colors

# %%
sns.cubehelix_palette(n_colors=6,reverse=True)

# %%
sns.cubehelix_palette(n_colors=3,reverse=True,hue=6)

# %% [markdown]
# ## creating custom color palette

# %%
sns.light_palette('red')

# %%
sns.light_palette('blue',n_colors=4)

# %%
sns.dark_palette('yellow')

# %%
import seaborn as sns

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_core',
#  '_decorators',
#  '_docstrings',
#  '_orig_rc_params',
#  '_statistics',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'factorplot',
#  'get_data_home',
#  'get_dataset_names',
#  'heatmap',
#  'histplot',
#  'hls_palette',
# ...

# %%
help(sns.catplot)
# Out:
# Help on function catplot in module seaborn.categorical:
#
# catplot(*, x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean at 0x000001300456EF70>, ci=95, n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, kind='strip', height=5, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)
#     Figure-level interface for drawing categorical plots onto a
#     :class:`FacetGrid`.
#
#     This function provides access to several axes-level functions that
#     show the relationship between a numerical and one or more categorical
#     variables using one of several visual representations. The ``kind``
#     parameter selects the underlying axes-level function to use:
#
#     Categorical scatterplots:
#
#     - :func:`stripplot` (with ``kind="strip"``; the default)
# ...

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.catplot(data=df)

# %% [markdown]
# ## kind support strip,bar,box
#  ## palette support views,

# %%
sns.catplot(data=df,kind='box')

# %%
sns.catplot(x='species',y='sepal_length',data=df,hue='petal_width',)

# %%
sns.catplot(x='sepal_width',y='sepal_length',data=df,hue='petal_width',)

# %%
sns.catplot(x='species',y='sepal_length',data=df,hue='species',kind='swarm')

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='petal_width',kind='box')

# %%
sns.catplot(x='sepal_length',y='species',data=df,hue='sepal_width',kind='swarm')

# %%
sns.catplot(x='petal_length',y='species',data=df,kind='bar',col='species')

# %%
sns.catplot(x='petal_length',y='petal_width',data=df,hue='species',kind='bar')

# %%
sns.catplot(x='petal_length',y='petal_width',data=df,hue='species',palette=['r','b','g'])

# %%
## Box plot
sns.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='day',y='tip',data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e0cf430dc6bb> in <module>
# ----> 1 sns.boxplot(x='day',y='tip',data=df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2228 ):
#    2229
# -> 2230     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2231                           orient, color, palette, saturation,
#    2232                           width, dodge, fliersize, linewidth)
#
# ...

# %%
## voilin plot
- bpx plot
- sns.violinplot
# Out:
#   File "<ipython-input-37-4a604c554f62>", line 2
#     - bpx plot
#           ^
# SyntaxError: invalid syntax

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df3=sns.load_dataset('dots')
df3.head(3)
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840

# %%
df3['align'].value_counts()
# Out:
# sacc    454
# dots    394
# Name: align, dtype: int64

# %%
sns.violinplot(x='align',y='firing_rate',data=df3,hue='choice',split=False)
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x='align',y='firing_rate',data=df3,hue='choice',dodge=False)
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x='align',y='firing_rate',data=df3,hue='choice',split=True)
sns.violinplot(x='align',y='firing_rate',data=df3,hue='choice',split=False)
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x='align',y='firing_rate',data=df3,hue='choice',inner='quartile')
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x='align',y='firing_rate',data=df3,hue='choice',inner='stick')
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %% [markdown]
# ## kde plot
# - kernal density estimate plot
# - didtribution data
# - sns.kdeplot(

# %%
sns.kdeplot(x='firing_rate',data=df3)
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='Density'>

# %%
sns.set_style('darkgrid')
sns.kdeplot(x='firing_rate',data=df3)
sns.set_context('paper')

# %% [markdown]
# ## categorical descrete plot
# - jointplot
# - joins the different plots together
# - sns.jointplot()

# %%
sns.jointplot(x='firing_rate',y='coherence',data=df3,hue='time')

# %%
sns.jointplot(x='firing_rate',y='coherence',data=df3,kind='reg')

# %%
sns.jointplot(x='firing_rate',y='coherence',data=df3,kind='hist',bins=2)

# %% [markdown]
# ## pair plot
# - it it displays a relationship b/w features(data)
# - sns.pairplot()

# %%
sns.pairplot(data=df3)

# %%
sns.pairplot(data=df3,hue='time')

# %%
df3['choice'].value_counts()
# Out:
# T2    430
# T1    418
# Name: choice, dtype: int64

# %%
sns.pairplot(data=df3,hue='choice')

# %%
sns.pairplot(data=df3,hue='choice',markers=['o','*'])

# %% [markdown]
# ## count plot
# sns.countplot()

# %%
sns.countplot(x='choice',data=df3)
# Out:
# <AxesSubplot:xlabel='choice', ylabel='count'>

# %%
sns.countplot(x='choice',data=df3,hue='align')
# Out:
# <AxesSubplot:xlabel='choice', ylabel='count'>

# %%
## Barplot
sns.barplot()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='firing_rate',y='choice',data=df3,hue='align')
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='choice'>

# %%
import numpy as np
sns.barplot(x='firing_rate',y='choice',data=df3,hue='align',estimator=np.std)
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='choice'>

# %%
## corialation forms sepal length ishigh corrialation at 1
## -1 is negative corrialation
df.head()
corr=df.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corr,annot=True)
## defines length in graph,corrialation increases from bottom to top
# Out:
# <AxesSubplot:>

# %%
## point plot
## df.head()
sns.pointplot(x='sepal_length',y='species',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>

# %%
sns.pointplot(x='sepal_length',y='species',data=df,join=False)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>
